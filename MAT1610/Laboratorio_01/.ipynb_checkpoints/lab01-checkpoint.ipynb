# %% [markdown]
# <div style="border-bottom: 4px solid #003366; margin-bottom: 20px; padding-bottom: 10px; display: flex; justify-content: space-between; align-items: center;">
#     <div style="flex-grow: 1;">
#         <h1 style="color: #003366; font-family: 'Helvetica', sans-serif; margin-bottom: 5px;">MAT1610: Cálculo I</h1>
#         <h2 style="color: #555; margin-top: 0; margin-bottom: 10px;">Laboratorio 01: Funciones</h2>
#         <p style="margin: 2px 0;"><b>Profesores:</b> XXX | <b>Fecha:</b> XX de XXX, 2026</p>
#         <p style="margin: 2px 0;"><b>Institución:</b> Facultad de Matemáticas, Pontificia Universidad Católica de Chile</p>
#     </div>
#     <div style="flex: 0 0 auto; margin-left: 20px;">
#         <img src="../source/FacMatematicas-15.png"
#              alt="Logo UC"
#              style="height: 60px; width: auto;">
#     </div>
#
# </div>
#
# <div style="border: 1px solid #2980b9; border-left: 8px solid #2980b9; padding: 15px; border-radius: 5px; margin-bottom: 20px;">
#     <h3 style="color: #2980b9; margin-top: 0;">Contenidos de la sesion</h3>
#     <ol>
#         <li>  Definicion de Funcion.</li>
#         <li>  Comportamiento de Funciones.</li>
#         <li>  Operacion de Funciones.</li>
#     </ol>
# </div>

# %%
# importar librerias de la sesion
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# INTENTO DE CONFIGURACIÓN DE ESTILO (Compatible con versiones viejas y nuevas)
try:
    plt.style.use('seaborn-v0_8-whitegrid') # Nombre nuevo (Matplotlib 3.6+)
except OSError:
    plt.style.use('seaborn-whitegrid')      # Nombre antiguo

plt.rcParams['figure.figsize'] = (6, 4)

print(f"Versión de Numpy: {np.__version__}")
# Out:
# Versión de Numpy: 1.24.4

# %% [markdown]
# # Definici&oacute;n de Funci&oacute;n
#
# Una funcion es una regla que asigna exactamente un valor de salidad a cada valor de entrada. Cuando una funcion $f$ tiene un valor de entrada $x$, el valor de salida se escribe como $f(x)$. Esto se lee como ``$f$ de $x$''
#
# En Cálculo, el objeto fundamental son las funciones. En Python, podemos definirlas usando la palabra clave def.
# Como ejemplo, consideremos la función cuadrática del examen de diagnóstico de Stewart:
# $$f(x)=x^2−2x+1$$
# Esta función representa una parábola.
# <!-- > **Ejemplo de funciones:**
# > - $f(x) = 2x-3$, funcion lineal, resulta de multiplicar la entrada  $x$ por 2 y luego restar $3$. Regresa el valor $2x-3$
# > - $g(x) = x^2 - 4$, funcion cuadratica.
# > - $h(x) = \sin(x)$, funcion sinusoidal. -->

# %%
# Definicion de funcion f(x) - parabola
def f(x): 
    return x**2-2*x+1
# Analogamente podemos definir funciones de tipo lambda
f = lambda x: x**2-2*x+1

# %%
# Evaluacion puntual de la funcion
punto_x = float(input("Ingrese el valor de entrada x ="))   
f_de_x = f(punto_x) 
print("El valor de salida f(x) =", f_de_x)
# Out:
# Ingrese el valor de entrada x = 6
# El valor de salida f(x) = 25.0

# %%
# Crear un dominio de x desde -2 hasta 4 con 10 puntos
x_valores = np.linspace(-2, 4, 10)
y_valores = f(x_valores)

print("   x  |   f(x)")
print("-" * 15)
for x, y in zip(x_valores, y_valores):
    print(f"{x:5.2f} | {y:5.2f}")
# Out:
#    x  |   f(x)
# ---------------
# -2.00 |  9.00
# -1.33 |  5.44
# -0.67 |  2.78
#  0.00 |  1.00
#  0.67 |  0.11
#  1.33 |  0.11
#  2.00 |  1.00
#  2.67 |  2.78
#  3.33 |  5.44
#  4.00 |  9.00

# %%
# grafica de las funcion
x = np.linspace(-3, 5, 100) # Dominio restringido por Stewart
# plt.figure(figsize=(8, 5))
plt.plot(x, f(x), label='$f(x) = x^{2}-2x+1$', color='red', linewidth=2)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)
plt.title('Representación Visual de una Función Par&aacute;bola')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # Comportamiento de Funciones

# %% [markdown]
# ## Funciones comunes: Lineas, exponenciales, logaritmica, sinuoidal

# %% [markdown]
# ### Funciones Trigonométricas
# En el Cálculo, por convención, siempre se utilizan medidas en radianes
# . Una función trigonométrica como f(x)=sin(x) se entiende como el seno de un ángulo cuya medida en radianes es x
# .
# Relación con el Círculo Unitario: Si consideramos un círculo de radio r=1 centrado en el origen (círculo unitario), cualquier punto P(x,y) sobre su circunferencia puede representarse en términos de un ángulo θ en posición estándar
# . Las coordenadas del punto son:
# x=cos(θ)
#
# y=sin(θ)
#  Debido a que el punto está en el círculo unitario, se cumple la identidad fundamental: sin
# 2
#  (θ)+cos
# 2
#  (θ)=1
# .

# %%
# Creación del círculo unitario para visualizar la relación
theta = np.linspace(0, 2*np.pi, 100)
x_puntos = np.cos(theta)
y_puntos = np.sin(theta)

fig, ax = plt.subplots(figsize=(6,6))
ax.plot(x_puntos, y_puntos, color='black', label='Círculo Unitario $x^2 + y^2 = 1$')

# Dibujar un ángulo de ejemplo (pi/3)
angulo = np.pi/3
px, py = np.cos(angulo), np.sin(angulo)
ax.plot([0, px], [0, py], 'ro-') # Radio
ax.text(px+0.05, py+0.05, f'P(cos θ, sen θ)\n({px:.2f}, {py:.2f})', color='red')

ax.axhline(0, color='gray', lw=1); ax.axvline(0, color='gray', lw=1)
ax.set_xlim(-1.5, 1.5); ax.set_ylim(-1.5, 1.5)
ax.set_aspect('equal')
ax.set_title("Relación entre el ángulo y las coordenadas")
ax.grid(True, linestyle=':')
plt.legend()
plt.show()

# %% [markdown]
# Para el estudio del Cálculo, es fundamental conocer los valores exactos de las funciones seno y coseno en ángulos clave del primer cuadrante

# %%
print(r"   x  |   $$\\pi/6$$  | ")
print("-" * 15)
for x, y in zip(x_valores, y_valores):
    print(f"{x:5.2f} | {y:5.2f}")
# Out:
#    x  |   $$\\pi/6$$  |
# ---------------
# -2.00 |  9.00
# -1.33 |  5.44
# -0.67 |  2.78
#  0.00 |  1.00
#  0.67 |  0.11
#  1.33 |  0.11
#  2.00 |  1.00
#  2.67 |  2.78
#  3.33 |  5.44
#  4.00 |  9.00

# %% [markdown]
# ## Composicion de Funciones

# %% [markdown]
# ## Inversa de Funciones

# %% [markdown]
# ---
# <div class="alert alert-block alert-success";  style="background-color: #e8f5e9; border-left: 5px solid #4caf50; padding: 15px; border-radius: 5px;">
#
# ## Ticket de Salida:
#
# <h3 style="color: #2e7d32; margin-top: 0;">💻 Ejercicios: </h3>
# </div>
#
# 1. Encuentre el dominio de las siguientes funciones.
# 2. Grafique las siguientes funciones en el intervalo
# 3. Dadas las funciones $f(x)$  y  $g(x)$ encuentre cada uno de los siguientes:
#     - $(f+g)(x)$ para $x=0.5$.
#     - $g \circ f(x) = g (f(x))$, para $x= 2.0$.

# %% [markdown]
# <div style="width: 100%; border-top: 2px solid #ddd; padding-top: 15px; margin-top: 30px; font-family: sans-serif; font-size: 0.85em; color: #666;">
#     <p>
#         <strong>© 2026 Manuel A. Sánchez </strong><br>
#         <a href="https://www.mat.uc.cl/" style="color: #003366; text-decoration: none;">Facultad de Matemáticas</a><br>
#         Pontificia Universidad Católica de Chile
#     </p>
#     <p>
#         <i>Este material está diseñado para el curso MAT1610 y no debe ser redistribuido sin permiso explícito.</i>
#     </p>
# </div>

# %% [markdown]
# ############# Markdown parser in Jupyter notebooks ##################
#
# <div class="alert alert-block alert-info"> <b>NOTE</b> Use blue boxes for Tips and notes. </div>
#
# <div class="alert alert-block alert-success"> Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook. </div>
#
# <div class="alert alert-block alert-warning"> Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed. </div>
#
# <div class="alert alert-block alert-danger"> In general, just avoid the red boxes. </div>
#
# ############# Markdown parser in Sphinx ##################
#
# <div class="admonition note"> <p class="admonition-title">Note</p> <p>You should note that the title will be automatically capitalized.</p> </div>
#
# <div class="admonition danger"> <p class="admonition-title">Don't try this at home</p> <p>...</p> </div>
#
# <div class="admonition important"> <p>This is an admonition box without a title.</p> </div>
