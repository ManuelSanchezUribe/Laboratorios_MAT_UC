# %% [markdown]
# <div style="border-bottom: 4px solid #003366; margin-bottom: 20px; padding-bottom: 10px; display: flex; justify-content: space-between; align-items: center;">
#     <div style="flex-grow: 1;">
#         <h1 style="color: #003366; font-family: 'Helvetica', sans-serif; margin-bottom: 5px;">MAT1610: Cálculo I</h1>
#         <h2 style="color: #555; margin-top: 0; margin-bottom: 10px;">Laboratorio 02: El Concepto de Límite</h2>
#         <p style="margin: 2px 0;"><b>Profesores:</b> Equipo Docente | <b>Fecha:</b> Agosto, 2026</p>
#         <p style="margin: 2px 0;"><b>Institución:</b> Facultad de Matemáticas, Pontificia Universidad Católica de Chile</p>
#     </div>
#     <div style="flex: 0 0 auto; margin-left: 20px;">
#         <img src="../source/FacMatematicas-15.png" alt="Logo UC" style="height: 60px; width: auto;">
#     </div>
# </div>

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

sp.init_printing()
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (8, 4)

# %% [markdown]
# # 1. Definición intuitiva y aproximación numérica
# Un límite nos dice a qué valor se acerca una función cuando la variable independiente se aproxima a un número. Usaremos tablas de valores.

# %% [markdown]
# # 2. Límites laterales y no existencia
# Analizamos qué ocurre cuando nos acercamos por la izquierda vs. la derecha. Si no coinciden, el límite no existe.

# %% [markdown]
# # 3. Propiedades de los límites
# Utilizaremos las leyes de los límites (suma, producto, cociente) para resolver límites de forma analítica con SymPy.

# %% [markdown]
# # 4. Definición formal (epsilon-delta)
# Ilustración gráfica de cómo, para cada epsilon, existe un delta que confina la función dentro de un intervalo deseado.

# %%
# Ejemplo de aproximación numérica:
# Definir f(x) = (x^2 - 1) / (x - 1)
# Evaluar en puntos cercanos a 1 desde ambos lados.
